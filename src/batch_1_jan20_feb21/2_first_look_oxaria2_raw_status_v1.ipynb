# %%
# Imports
#---------
import sys
import pandas as pd
import numpy as np
import feather
import os
import gc
import datetime as dt
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from pandas.plotting import register_matplotlib_converters
import matplotlib.ticker as ticker
from matplotlib.dates import DateFormatter
import matplotlib as mpl
import qgrid

register_matplotlib_converters()

# File locations
#----------------
the_gases = './oxaria/data/raw/2oxaria/json/'
pngs = './oxaria/data/pngs/'

# %%
# Load the df 
#-------------
oxaria2_status = pd.read_feather(the_gases+'oxaria2_status_jul_nov2020.ftr').set_index(['tag','rec']).sort_index()

# %%
oxaria2_status.head()
# Out:
#                                        val.sch.scs-particulates.tally  \
# tag         rec
# scs-bgx-550 2020-07-01 00:00:42+00:00                               1
#             2020-07-01 00:01:42+00:00                               1
#             2020-07-01 00:02:42+00:00                               1
#             2020-07-01 00:03:42+00:00                               1
#             2020-07-01 00:04:42+00:00                               1
#
#                                        val.sch.scs-particulates.interval  \
# tag         rec
# scs-bgx-550 2020-07-01 00:00:42+00:00                                 10
#             2020-07-01 00:01:42+00:00                                 10
#             2020-07-01 00:02:42+00:00                                 10
#             2020-07-01 00:03:42+00:00                                 10
#             2020-07-01 00:04:42+00:00                                 10
#
#                                        val.sch.scs-status.tally  \
# tag         rec
# scs-bgx-550 2020-07-01 00:00:42+00:00                         1
#             2020-07-01 00:01:42+00:00                         1
#             2020-07-01 00:02:42+00:00                         1
#             2020-07-01 00:03:42+00:00                         1
#             2020-07-01 00:04:42+00:00                         1
#
#                                        val.sch.scs-status.interval  \
# tag         rec
# scs-bgx-550 2020-07-01 00:00:42+00:00                           60
#             2020-07-01 00:01:42+00:00                           60
#             2020-07-01 00:02:42+00:00                           60
#             2020-07-01 00:03:42+00:00                           60
#             2020-07-01 00:04:42+00:00                           60
#
#                                        val.sch.scs-climate.tally  \
# tag         rec
# scs-bgx-550 2020-07-01 00:00:42+00:00                          1
#             2020-07-01 00:01:42+00:00                          1
#             2020-07-01 00:02:42+00:00                          1
#             2020-07-01 00:03:42+00:00                          1
#             2020-07-01 00:04:42+00:00                          1
#
#                                        val.sch.scs-climate.interval  \
# tag         rec
# scs-bgx-550 2020-07-01 00:00:42+00:00                            60
#             2020-07-01 00:01:42+00:00                            60
#             2020-07-01 00:02:42+00:00                            60
#             2020-07-01 00:03:42+00:00                            60
#             2020-07-01 00:04:42+00:00                            60
#
#                                        val.sch.scs-gases.tally  \
# tag         rec
# scs-bgx-550 2020-07-01 00:00:42+00:00                        1
#             2020-07-01 00:01:42+00:00                        1
#             2020-07-01 00:02:42+00:00                        1
#             2020-07-01 00:03:42+00:00                        1
#             2020-07-01 00:04:42+00:00                        1
#
#                                        val.sch.scs-gases.interval  \
# tag         rec
# scs-bgx-550 2020-07-01 00:00:42+00:00                          10
#             2020-07-01 00:01:42+00:00                          10
#             2020-07-01 00:02:42+00:00                          10
#             2020-07-01 00:03:42+00:00                          10
#             2020-07-01 00:04:42+00:00                          10
#
#                                        val.gps.pos:0  val.gps.pos:1  ...  \
# tag         rec                                                      ...
# scs-bgx-550 2020-07-01 00:00:42+00:00      51.761814      -1.240110  ...
#             2020-07-01 00:01:42+00:00      51.761822      -1.240102  ...
#             2020-07-01 00:02:42+00:00      51.761826      -1.240096  ...
#             2020-07-01 00:03:42+00:00      51.761826      -1.240091  ...
#             2020-07-01 00:04:42+00:00      51.761822      -1.240086  ...
#
#                                        val.psu.prot-batt  val.psu.rst  \
# tag         rec
# scs-bgx-550 2020-07-01 00:00:42+00:00                8.4            0
#             2020-07-01 00:01:42+00:00                8.4            0
#             2020-07-01 00:02:42+00:00                8.4            0
#             2020-07-01 00:03:42+00:00                8.4            0
#             2020-07-01 00:04:42+00:00                8.4            0
#
#                                        val.psu.chg  val.psu.standby  \
# tag         rec
# scs-bgx-550 2020-07-01 00:00:42+00:00         1000            False
#             2020-07-01 00:01:42+00:00         1000            False
#             2020-07-01 00:02:42+00:00         1000            False
#             2020-07-01 00:03:42+00:00         1000            False
#             2020-07-01 00:04:42+00:00         1000            False
#
#                                        val.psu.pwr-in val.psu.host-3v3  \
# tag         rec
# scs-bgx-550 2020-07-01 00:00:42+00:00            12.5              3.3
#             2020-07-01 00:01:42+00:00            12.5              3.3
#             2020-07-01 00:02:42+00:00            12.5              3.3
#             2020-07-01 00:03:42+00:00            12.5              3.3
#             2020-07-01 00:04:42+00:00            12.5              3.3
#
#                                        val.psu.batt-flt    val.tz.name  \
# tag         rec
# scs-bgx-550 2020-07-01 00:00:42+00:00             False  Europe/London
#             2020-07-01 00:01:42+00:00             False  Europe/London
#             2020-07-01 00:02:42+00:00             False  Europe/London
#             2020-07-01 00:03:42+00:00             False  Europe/London
#             2020-07-01 00:04:42+00:00             False  Europe/London
#
#                                        val.tz.utc-offset  val.tmp.brd
# tag         rec
# scs-bgx-550 2020-07-01 00:00:42+00:00             +01:00         26.6
#             2020-07-01 00:01:42+00:00             +01:00         26.6
#             2020-07-01 00:02:42+00:00             +01:00         26.6
#             2020-07-01 00:03:42+00:00             +01:00         26.6
#             2020-07-01 00:04:42+00:00             +01:00         26.6
#
# [5 rows x 27 columns]

# %%
# Loop through plots with a log scale to compare time series & size fractions

plt.style.use('ggplot')
#plt.tight_layout()
myFmt = mdates.DateFormatter('%b')
start_date=dt.datetime(2020,1,1)
end_date=dt.datetime(2020,12,31)

fig, axes = plt.subplots(nrows=5, ncols=2, sharex=False, sharey=False, figsize=(15,20))
axes_list = [item for sublist in axes for item in sublist] 

fig.suptitle('Raw OxAria2 board temperature / sensor status outputs, January 2020 onward', fontsize=11.5, y=0.91)

for tag, dat in oxaria2_status.groupby('tag'):
    ax = axes_list.pop(0)
    dat.reset_index(level=0,inplace=True)
    #t_name = dat['name'].unique()
    dat.plot(y='val.tmp.brd', c='tab:blue',linewidth=0.5, marker='o', ms=0.1, ls='', label='Board temp.', ax=ax, legend=True, \
            zorder=1)
    ax.set_title(tag, fontsize=10)
    ax.tick_params(
        axis='x',
        which='major',
        labelrotation=0,
        labelsize=8
        )
    ax.tick_params(axis='y', labelsize=9)
    ax.tick_params(axis='x', which='minor', length=0)
    ax.xaxis.set_major_locator(ticker.MultipleLocator(28))
    ax.xaxis.set_major_formatter(myFmt)
    plt.setp(ax.xaxis.get_majorticklabels(), ha='center')
    ax.set_xlim(start_date, end_date)
    ax.set_ylabel('val.tmp.brd (deg C)', fontsize=8)
    ax.set_xlabel('')
    plt.subplots_adjust(wspace=0.14, hspace=0.3)
    ax.legend(markerscale=40, frameon=True, framealpha=0.99, loc='upper right') 
    
plt.savefig(pngs+'oxaria2_bdrtmp_raw_sensor_ts.png')
plt.show()    
    
for ax in axes_list:
    ax.remove()
