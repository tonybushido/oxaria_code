# %%
# Imports
#---------
import sys
import pandas as pd
import numpy as np
import feather
import os
import gc
import datetime as dt
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from pandas.plotting import register_matplotlib_converters
import matplotlib.ticker as ticker
from matplotlib.ticker import FuncFormatter
from matplotlib.dates import DateFormatter, MonthLocator, DayLocator
import matplotlib as mpl
import peakutils
import warnings
import pytz
import seaborn as sns
from scipy import stats
import copy
from scipy.stats import wilcoxon
import seaborn as sns
from matplotlib.patches import Rectangle

warnings.filterwarnings("ignore")

register_matplotlib_converters()

# File locations
#----------------
#the_gases = '/home/tonyb/Gdrive/MinicondaProjects/oxaria/data/raw/1oxaria/json/gap_filling/'
pngs = '/home/tonyb/Gdrive/MinicondaProjects/oxaria/data/gap_filling/536_method/lockdown_stats/pngs/'
data_home = '/home/tonyb/Gdrive/MinicondaProjects/oxaria/data/raw/0oxaria/gap_filling/jun_to_sept_2021/'
stats_home = '/home/tonyb/Gdrive/MinicondaProjects/oxaria/data/gap_filling/536_method/lockdown_stats/'
aurn_path = '/home/tonyb/Gdrive/MinicondaProjects/oxaria/data/aurn/aurn_2016_2021/'


cmap = copy.copy(plt.cm.get_cmap("Blues"))
cmap.set_under("white")

def color_nan_white(val):
#     """Color the nan text white"""
    if np.isnan(val):
        return 'color: white'

def color_nan_white_background(val):
#      """Color the nan cell background white"""
    if np.isnan(val):
        return 'background-color: white'
    
def color_nonnan_black(val):
#     """Color the non-nan text white"""
    if pd.notna(val):
        return 'color: black'
    
def _color_red_or_green(val):
    color = 'red' if val < 0 else 'green'
    return 'color: %s' % color

# %%
# Load senssor data at 24hr resolution
#--------------------------------------
sensors_24hr = pd.read_feather(stats_home+'sensors_24hr.ftr').drop('index', axis=1)

# Load sebbes typical values 2016-21 for graphing
#-------------------------------------------------
sebbes_pm10_ld_event_desc_mean = pd.read_feather(stats_home+'sebbes_ordinal_daymean_codeup_ak_mean_desc_pm10_1619.ftr')
sebbes_pm25_ld_event_desc_mean = pd.read_feather(stats_home+'sebbes_ordinal_daymean_codeup_ak_mean_desc_pm25_1619.ftr')

# Load sebbes data with ordinal day & LD event codes
#-----------------------------------------------------
sebbes_ordinal_daymean_codeup_ak = pd.read_feather(stats_home+'sebbes_ordinal_daymean_codeup_ak_1619.ftr')

# %%
sensors_24hr['fname'].unique()
# Out:
# array(['County Hall', 'Divinity Road', 'High St', 'Jahlul Bayt Mosque',
#        'Jesus College', 'John Radcliffe', 'New Marsten',
#        'Said Business School', 'South Parks Rd', 'Speedwell St',
#        'St Ebbes', 'St Giles', 'The Plain', 'Warneford Hospital',
#        'Worcester College'], dtype=object)

# %%
# Fill gaps in data with NaNs for easy plotting - pm10
#------------------------------------------------------

sensor_ld_event_stats = sensors_24hr.groupby(['fname','ld_code']).mean().sort_values(['fname','ld_code'])
sensors = pd.DataFrame(sorted(list(sensor_ld_event_stats.index.get_level_values(0).unique())), columns=['sensor'])
events = pd.DataFrame(sorted(['a','b','c','d','e','f','g','h','i','j','k']))

tmplist = []
for i, j in sensors.iterrows():
    for ii, jj in events.iterrows():
        tmp = pd.DataFrame(zip(j,jj), columns=['sensors','events'])
        tmplist.append(tmp)
sevents = pd.concat(tmplist).reset_index(drop=True)

sensor_ld_event_stats_1 = sevents.merge(sensor_ld_event_stats.reset_index(), left_on=['sensors','events'], right_on=['fname','ld_code'], how='left')
sensor_ld_event_stats_1['ld_code'] = sensor_ld_event_stats_1['events']
sensor_ld_event_stats_1['fname'] = sensor_ld_event_stats_1['sensors']
sensor_ld_event_stats_1.drop(['sensors','events'], inplace=True, axis=1)
sensor_ld_event_stats_1.set_index('ld_code', inplace=True)

sensors_24hr
# Out:
#                   fname                       rec  pm10_count  pm10_mean  \
# 0           County Hall 2020-12-15 00:00:00+00:00        87.0   6.612950
# 1           County Hall 2020-12-16 00:00:00+00:00        80.0   7.339553
# 2           County Hall 2020-12-17 00:00:00+00:00        96.0   8.003825
# 3           County Hall 2020-12-18 00:00:00+00:00        87.0   4.810527
# 4           County Hall 2020-12-19 00:00:00+00:00        96.0   7.727195
# ...                 ...                       ...         ...        ...
# 6102  Worcester College 2021-09-27 00:00:00+00:00        41.0   5.782544
# 6103  Worcester College 2021-09-28 00:00:00+00:00        58.0   8.334442
# 6104  Worcester College 2021-09-29 00:00:00+00:00        12.0   5.580304
# 6105  Worcester College 2021-09-30 00:00:00+00:00        43.0   7.241805
# 6106  Worcester College 2021-10-01 00:00:00+00:00         0.0        NaN
#
#       pm10_std  pm10_min  pm10_p50   pm10_p99   pm10_max  pm25_count  \
# 0     1.229592  4.919706  6.440050   9.770505  12.739062        90.0
# 1     1.004997  3.902992  7.475995   9.826809  10.219915        87.0
# 2     1.676295  4.112205  8.221502  11.633351  12.305089        96.0
# 3     1.701859  2.592747  4.220860   9.560819   9.567860        96.0
# 4     2.366524  4.126148  7.044486  12.592371  12.622390        96.0
# ...        ...       ...       ...        ...        ...         ...
# 6102  1.554335  3.203328  5.780949   8.702189   9.029831        49.0
# 6103  1.731578  3.752732  8.286094  11.972597  12.310269        61.0
# 6104  2.033892  3.484669  4.962007  10.031972  10.172286        14.0
# 6105  2.645207  3.251400  7.026726  14.314870  15.181786        51.0
# 6106       NaN       NaN       NaN        NaN        NaN         1.0
#
#       pm25_mean  pm25_std  pm25_min  pm25_p50   pm25_p99   pm25_max  \
# 0      5.343533  1.428886  2.368662  5.644143   8.033531   8.089935
# 1      4.345923  1.386274  1.127552  4.390406   7.934518   8.462211
# 2      6.041280  0.938746  4.063359  5.959664   8.167700   9.206308
# 3      3.445602  1.559260  0.866599  3.054144   7.060478   8.602067
# 4      6.919402  1.979501  2.622704  6.752164  12.055009  12.941072
# ...         ...       ...       ...       ...        ...        ...
# 6102   3.562348  1.174231  0.650043  3.756657   5.425359   5.476766
# 6103   5.419416  1.215315  0.995001  5.477320   8.073575   9.116414
# 6104   2.901159  0.965911  1.510046  2.606783   4.620429   4.628774
# 6105   3.513054  2.081902  0.600500  3.866543   7.669174   8.954279
# 6106   0.415794       NaN  0.415794  0.415794   0.415794   0.415794
#
#       ordinal_hrs  ordinal_days ld_code
# 0               0           350       f
# 1               0           351       f
# 2               0           352       f
# 3               0           353       f
# 4               0           354       f
# ...           ...           ...     ...
# 6102            0           270       k
# 6103            0           271       k
# 6104            0           272       k
# 6105            0           273       k
# 6106            0           274       k
#
# [6107 rows x 19 columns]

# %%
# Create matched-paired data sensor-sebbes data for each sensor by fname & lockdown event, merging data on ordinal day
#----------------------------------------------------------------------------------------------------------------------
tmplist = []
for i, g in sensors_24hr.iloc[:,[0,1,3,7,10,14,17,18]].groupby(['fname','ld_code']):
    gg = g.merge(sebbes_ordinal_daymean_codeup_ak[['pm10_mean','pm10_99%','pm25_mean','pm25_99%','ld_code','date']].query('ld_code == @i[1]'), 
                 left_on='ordinal_days', 
                 right_on='date',
                 how='outer',
                 suffixes=(None,'_s')).rename(columns={'pm10_99%':'pm10_p99_s','pm25_99%':'pm25_p99_s'})
    tmplist.append(gg)
sensor_sebbes = pd.concat(tmplist).dropna(axis=0, subset=['rec','pm10_mean'])
sensor_sebbes.reset_index().to_feather(stats_home+'sensor_sebbes_24hr.ftr')
sensor_sebbes
# Out:
#                  fname                       rec  pm10_mean   pm10_p99  \
# 0          County Hall 2020-12-15 00:00:00+00:00   6.612950   9.770505
# 1          County Hall 2020-12-16 00:00:00+00:00   7.339553   9.826809
# 2          County Hall 2020-12-17 00:00:00+00:00   8.003825  11.633351
# 3          County Hall 2020-12-18 00:00:00+00:00   4.810527   9.560819
# 4          County Hall 2020-12-19 00:00:00+00:00   7.727195  12.592371
# ..                 ...                       ...        ...        ...
# 97   Worcester College 2021-09-26 00:00:00+00:00  12.629374  29.923689
# 98   Worcester College 2021-09-27 00:00:00+00:00   5.782544   8.702189
# 99   Worcester College 2021-09-28 00:00:00+00:00   8.334442  11.972597
# 100  Worcester College 2021-09-29 00:00:00+00:00   5.580304  10.031972
# 101  Worcester College 2021-09-30 00:00:00+00:00   7.241805  14.314870
#
#      pm25_mean   pm25_p99  ordinal_days ld_code  pm10_mean_s  pm10_p99_s  \
# 0     5.343533   8.033531         350.0       f     9.027431      16.275
# 1     4.345923   7.934518         351.0       f    11.169792      19.422
# 2     6.041280   8.167700         352.0       f    12.659722      32.214
# 3     3.445602   7.060478         353.0       f    13.173958      30.658
# 4     6.919402  12.055009         354.0       f     7.965278      20.951
# ..         ...        ...           ...     ...          ...         ...
# 97   10.416576  25.616667         269.0       k    18.635417      51.661
# 98    3.562348   5.425359         270.0       k    19.680903      52.963
# 99    5.419416   8.073575         271.0       k     7.906250      13.532
# 100   2.901159   4.620429         272.0       k     8.886806      23.606
# 101   3.513054   7.669174         273.0       k     8.722917      18.354
#
#      pm25_mean_s  pm25_p99_s ld_code_s  date
# 0       4.809255    13.04084         f   350
# 1       7.732708    15.47626         f   351
# 2       7.453292    25.83600         f   352
# 3       8.572127    23.28000         f   353
# 4       5.798817    18.53000         f   354
# ..           ...         ...       ...   ...
# 97     15.073153    54.07500         k   269
# 98     14.914194    51.40700         k   270
# 99      4.218806    10.84500         k   271
# 100     5.504917    17.07700         k   272
# 101     5.317889    13.63200         k   273
#
# [6016 rows x 14 columns]

# %%
sensor_sebbes.groupby('fname').boxplot(column=['pm10_mean'], figsize=(18,16))
plt.show()

# %%
# Creat a table of differentials - pm10 mean
#---------------------------------------------
df = sensor_ld_event_stats_1.iloc[:,[0,1,2,3,4,5,6,7,8]].reset_index().merge(sebbes_pm10_ld_event_desc_mean[['ld_code','pm10_mean','pm10_99%']], 
                                                             left_on='ld_code',
                                                             right_on='ld_code',
                                                             how='left',
                                                             suffixes=(None,'_s')
                                                            ).rename(columns={'pm10_99%':'pm10_p99_s'})
df['dif_pm10_mean'] = df['pm10_mean'] - df['pm10_mean_s']
df['dif_pm10_99'] = df['pm10_p99'] - df['pm10_p99_s']

df = df.rename(columns={'ld_code': 'Event code', 'fname': 'Sensor'})
dif_pm10_mean = df[['Event code','Sensor','dif_pm10_mean']].pivot(index='Sensor',columns='Event code').round(1).droplevel(0, axis=1)
dif_pm10_mean.loc['Mean',:] = dif_pm10_mean.mean(axis=0)
dif_pm10_mean.loc[:,'Mean'] = dif_pm10_mean.mean(axis=1)

tmplist = []
for i, g in sensor_sebbes.groupby(['fname','ld_code']):
    stat, p = wilcoxon(g['pm10_mean'].values, g['pm10_mean_s'].values) 
    tmplist.append([i[0],i[1],stat,p])
pm10_mean_wilcoxon = pd.DataFrame(tmplist, columns = ['fname','ld_code', 'stat', 'P'])

dif_pm10_p99 = df[['Event code','Sensor','dif_pm10_99']].pivot(index='Sensor',columns='Event code').round(1).droplevel(0, axis=1)
dif_pm10_p99.loc['Mean',:] = dif_pm10_p99.mean(axis=0)
dif_pm10_p99.loc[:,'Mean'] = dif_pm10_p99.mean(axis=1)

tmplist = []
for i, g in sensor_sebbes.groupby(['fname','ld_code']):
    stat, p = wilcoxon(g['pm10_p99'].values, g['pm10_p99_s'].values) 
    tmplist.append([i[0],i[1],stat,p])
pm10_p99_wilcoxon = pd.DataFrame(tmplist, columns = ['fname','ld_code', 'stat', 'P'])

pm10_mean_wilcoxon_a = pm10_mean_wilcoxon[['fname','ld_code', 'P']].pivot(index='fname',columns='ld_code').droplevel(0, axis=1)
pm10_mean_wilcoxon_a.loc['Mean',:] = pm10_mean_wilcoxon_a.mean(axis=0)
pm10_mean_wilcoxon_a.loc[:,'Mean'] = pm10_mean_wilcoxon_a.mean(axis=1)

pm10_p99_wilcoxon_a = pm10_p99_wilcoxon[['fname','ld_code', 'P']].pivot(index='fname',columns='ld_code').droplevel(0, axis=1)
pm10_p99_wilcoxon_a.loc['Mean',:] = pm10_p99_wilcoxon_a.mean(axis=0)
pm10_p99_wilcoxon_a.loc[:,'Mean'] = pm10_p99_wilcoxon_a.mean(axis=1)

display(dif_pm10_mean.style
    .background_gradient(axis=None)
    .applymap(lambda x: color_nan_white_background(x))
    .applymap(lambda x: color_nonnan_black(x))
    .applymap(lambda x: color_nan_white(x))
         .apply(lambda x: np.where(
    pm10_mean_wilcoxon_a < 0.05,               # Compare DataFrames
    'color: red',  # True Styles
    ''                       # False Styles
), axis=None).apply(lambda x: np.where(
    pm10_mean_wilcoxon_a < 0.05,               # Compare DataFrames
    'font-weight: bold',  # True Styles
    ''                       # False Styles
), axis=None).format("{:.1f}"),
        dif_pm10_p99.style
    .background_gradient(axis=None)
    .applymap(lambda x: color_nan_white_background(x))
    .applymap(lambda x: color_nonnan_black(x))
    .applymap(lambda x: color_nan_white(x))
         .apply(lambda x: np.where(
    pm10_p99_wilcoxon_a < 0.05,               # Compare DataFrames
    'color: red',  # True Styles
    ''                       # False Styles
), axis=None).apply(lambda x: np.where(
    pm10_p99_wilcoxon_a < 0.05,               # Compare DataFrames
    'font-weight: bold',  # True Styles
    ''                       # False Styles
), axis=None).format("{:.1f}")
       )
# Out:
# <style type="text/css">
# #T_6a167_row0_col0, #T_6a167_row0_col1, #T_6a167_row0_col2, #T_6a167_row0_col3, #T_6a167_row0_col4, #T_6a167_row1_col0, #T_6a167_row1_col1, #T_6a167_row2_col0, #T_6a167_row2_col1, #T_6a167_row2_col2, #T_6a167_row3_col0, #T_6a167_row3_col1, #T_6a167_row5_col0, #T_6a167_row5_col1, #T_6a167_row5_col2, #T_6a167_row5_col3, #T_6a167_row5_col4, #T_6a167_row6_col0, #T_6a167_row6_col1, #T_6a167_row6_col10, #T_6a167_row7_col0, #T_6a167_row7_col1, #T_6a167_row8_col0, #T_6a167_row8_col1, #T_6a167_row9_col0, #T_6a167_row9_col1, #T_6a167_row9_col2, #T_6a167_row9_col3, #T_6a167_row9_col4, #T_6a167_row10_col0, #T_6a167_row10_col1, #T_6a167_row11_col0, #T_6a167_row11_col1, #T_6a167_row13_col0, #T_6a167_row13_col1, #T_6a167_row13_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: white;
#   color: white;
# }
# #T_6a167_row0_col5 {
#   background-color: #9fbad9;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row0_col6 {
#   background-color: #d0d1e6;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row0_col7, #T_6a167_row10_col6 {
#   background-color: #e5e1ef;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row0_col8, #T_6a167_row14_col3 {
#   background-color: #cacee5;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row0_col9, #T_6a167_row7_col9, #T_6a167_row12_col1 {
#   background-color: #b3c3de;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row0_col10, #T_6a167_row4_col7, #T_6a167_row7_col4 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
#   color: black;
# }
# #T_6a167_row0_col11, #T_6a167_row3_col11, #T_6a167_row15_col7 {
#   background-color: #b8c6e0;
#   color: #000000;
#   color: black;
# }
# #T_6a167_row1_col2 {
#   background-color: #046198;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row1_col3 {
#   background-color: #2484ba;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row1_col4 {
#   background-color: #04639b;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row1_col5 {
#   background-color: #157ab5;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row1_col6, #T_6a167_row4_col11 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
#   color: black;
# }
# #T_6a167_row1_col7 {
#   background-color: #308cbe;
#   color: #f1f1f1;
#   color: black;
# }
# #T_6a167_row1_col8, #T_6a167_row15_col4 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
#   color: black;
# }
# #T_6a167_row1_col9 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
#   color: black;
# }
# #T_6a167_row1_col10, #T_6a167_row6_col4 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
#   color: black;
# }
# #T_6a167_row1_col11 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
#   color: black;
# }
# #T_6a167_row2_col3 {
#   background-color: #045f95;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row2_col4 {
#   background-color: #023d60;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row2_col5, #T_6a167_row4_col4 {
#   background-color: #1077b4;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row2_col6 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
#   color: black;
# }
# #T_6a167_row2_col7 {
#   background-color: #04649d;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row2_col8 {
#   background-color: #0771b1;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row2_col9, #T_6a167_row4_col1 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
#   color: black;
# }
# #T_6a167_row2_col10 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row2_col11 {
#   background-color: #0570b0;
#   color: #f1f1f1;
#   color: black;
# }
# #T_6a167_row3_col2 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row3_col3, #T_6a167_row7_col3, #T_6a167_row11_col4, #T_6a167_row14_col0 {
#   background-color: #bfc9e1;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row3_col4, #T_6a167_row8_col7 {
#   background-color: #78abd0;
#   color: #f1f1f1;
#   color: black;
# }
# #T_6a167_row3_col5, #T_6a167_row7_col5 {
#   background-color: #9cb9d9;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row3_col6, #T_6a167_row11_col11 {
#   background-color: #dbdaeb;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row3_col7 {
#   background-color: #ede8f3;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row3_col8, #T_6a167_row9_col11 {
#   background-color: #d9d8ea;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row3_col9 {
#   background-color: #c8cde4;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row3_col10, #T_6a167_row14_col2 {
#   background-color: #93b5d6;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row4_col0, #T_6a167_row12_col4 {
#   background-color: #88b1d4;
#   color: #000000;
#   color: black;
# }
# #T_6a167_row4_col2, #T_6a167_row7_col10, #T_6a167_row12_col2 {
#   background-color: #91b5d6;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row4_col3 {
#   background-color: #8cb3d5;
#   color: #000000;
#   color: black;
# }
# #T_6a167_row4_col5 {
#   background-color: #1379b5;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row4_col6, #T_6a167_row14_col11 {
#   background-color: #549cc7;
#   color: #f1f1f1;
#   color: black;
# }
# #T_6a167_row4_col8 {
#   background-color: #1379b5;
#   color: #f1f1f1;
#   color: black;
# }
# #T_6a167_row4_col9, #T_6a167_row10_col5 {
#   background-color: #97b7d7;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row4_col10, #T_6a167_row13_col4 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
#   color: black;
# }
# #T_6a167_row5_col5 {
#   background-color: #358fc0;
#   color: #f1f1f1;
#   color: black;
# }
# #T_6a167_row5_col6, #T_6a167_row12_col10 {
#   background-color: #a5bddb;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row5_col7, #T_6a167_row7_col2 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
#   color: black;
# }
# #T_6a167_row5_col8, #T_6a167_row15_col10 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
#   color: black;
# }
# #T_6a167_row5_col9 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
#   color: black;
# }
# #T_6a167_row5_col10 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row5_col11 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
#   color: black;
# }
# #T_6a167_row6_col2 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row6_col3 {
#   background-color: #9ab8d8;
#   color: #000000;
#   color: black;
# }
# #T_6a167_row6_col5 {
#   background-color: #81aed2;
#   color: #f1f1f1;
#   color: black;
# }
# #T_6a167_row6_col6 {
#   background-color: #e8e4f0;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row6_col7, #T_6a167_row9_col7, #T_6a167_row10_col7, #T_6a167_row10_col8 {
#   background-color: #f5eef6;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row6_col8, #T_6a167_row13_col8 {
#   background-color: #e9e5f1;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row6_col9 {
#   background-color: #d6d6e9;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row6_col11 {
#   background-color: #b4c4df;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row7_col6 {
#   background-color: #dad9ea;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_6a167_row7_col7 {
#   background-color: #c8cde4;
#   color: #000000;
#   color: black;
# }
# #T_6a167_row7_col8 {
#   background-color: #d5d5e8;
# <style type="text/css">
# #T_4f9d0_row0_col0, #T_4f9d0_row0_col1, #T_4f9d0_row0_col2, #T_4f9d0_row0_col3, #T_4f9d0_row0_col4, #T_4f9d0_row1_col0, #T_4f9d0_row1_col1, #T_4f9d0_row2_col0, #T_4f9d0_row2_col1, #T_4f9d0_row2_col2, #T_4f9d0_row3_col0, #T_4f9d0_row3_col1, #T_4f9d0_row5_col0, #T_4f9d0_row5_col1, #T_4f9d0_row5_col2, #T_4f9d0_row5_col3, #T_4f9d0_row5_col4, #T_4f9d0_row6_col0, #T_4f9d0_row6_col1, #T_4f9d0_row6_col10, #T_4f9d0_row7_col0, #T_4f9d0_row7_col1, #T_4f9d0_row8_col0, #T_4f9d0_row8_col1, #T_4f9d0_row9_col0, #T_4f9d0_row9_col1, #T_4f9d0_row9_col2, #T_4f9d0_row9_col3, #T_4f9d0_row9_col4, #T_4f9d0_row10_col0, #T_4f9d0_row10_col1, #T_4f9d0_row11_col0, #T_4f9d0_row11_col1, #T_4f9d0_row13_col0, #T_4f9d0_row13_col1, #T_4f9d0_row13_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: white;
#   color: white;
# }
# #T_4f9d0_row0_col5, #T_4f9d0_row0_col9, #T_4f9d0_row7_col9, #T_4f9d0_row13_col5, #T_4f9d0_row13_col10 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row0_col6 {
#   background-color: #cdd0e5;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row0_col7, #T_4f9d0_row10_col8 {
#   background-color: #e7e3f0;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row0_col8 {
#   background-color: #c0c9e2;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row0_col10, #T_4f9d0_row4_col10 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
#   color: black;
# }
# #T_4f9d0_row0_col11 {
#   background-color: #9ab8d8;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row1_col2 {
#   background-color: #045b8e;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row1_col3, #T_4f9d0_row6_col2 {
#   background-color: #4496c3;
#   color: #f1f1f1;
#   color: black;
# }
# #T_4f9d0_row1_col4 {
#   background-color: #045280;
#   color: #f1f1f1;
#   color: black;
# }
# #T_4f9d0_row1_col5 {
#   background-color: #157ab5;
#   color: #f1f1f1;
#   color: black;
# }
# #T_4f9d0_row1_col6 {
#   background-color: #8fb4d6;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row1_col7, #T_4f9d0_row6_col3, #T_4f9d0_row6_col9, #T_4f9d0_row12_col9 {
#   background-color: #93b5d6;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row1_col8 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
#   color: black;
# }
# #T_4f9d0_row1_col9 {
#   background-color: #2383ba;
#   color: #f1f1f1;
#   color: black;
# }
# #T_4f9d0_row1_col10, #T_4f9d0_row4_col4 {
#   background-color: #0566a0;
#   color: #f1f1f1;
#   color: black;
# }
# #T_4f9d0_row1_col11 {
#   background-color: #2786bb;
#   color: #f1f1f1;
#   color: black;
# }
# #T_4f9d0_row2_col3 {
#   background-color: #04629a;
#   color: #f1f1f1;
#   color: black;
# }
# #T_4f9d0_row2_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row2_col5 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
#   color: black;
# }
# #T_4f9d0_row2_col6 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row2_col7 {
#   background-color: #1278b4;
#   color: #f1f1f1;
#   color: black;
# }
# #T_4f9d0_row2_col8 {
#   background-color: #04588a;
#   color: #f1f1f1;
#   color: black;
# }
# #T_4f9d0_row2_col9 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
#   color: black;
# }
# #T_4f9d0_row2_col10 {
#   background-color: #04649d;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row2_col11, #T_4f9d0_row14_col7 {
#   background-color: #056caa;
#   color: #f1f1f1;
#   color: black;
# }
# #T_4f9d0_row3_col2, #T_4f9d0_row7_col10 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row3_col3 {
#   background-color: #b4c4df;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row3_col4 {
#   background-color: #308cbe;
#   color: #f1f1f1;
#   color: black;
# }
# #T_4f9d0_row3_col5 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row3_col6 {
#   background-color: #d9d8ea;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row3_col7 {
#   background-color: #f4eef6;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row3_col8 {
#   background-color: #d0d1e6;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row3_col9 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row3_col10, #T_4f9d0_row6_col5, #T_4f9d0_row10_col2 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row3_col11 {
#   background-color: #97b7d7;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row4_col0, #T_4f9d0_row5_col7, #T_4f9d0_row11_col9, #T_4f9d0_row13_col11 {
#   background-color: #a5bddb;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row4_col1 {
#   background-color: #8bb2d4;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row4_col2 {
#   background-color: #4295c3;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row4_col3 {
#   background-color: #86b0d3;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row4_col5, #T_4f9d0_row5_col5 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
#   color: black;
# }
# #T_4f9d0_row4_col6, #T_4f9d0_row11_col10, #T_4f9d0_row12_col5 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row4_col7 {
#   background-color: #acc0dd;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row4_col8 {
#   background-color: #03446a;
#   color: #f1f1f1;
#   color: black;
# }
# #T_4f9d0_row4_col9 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row4_col11, #T_4f9d0_row15_col5 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
#   color: black;
# }
# #T_4f9d0_row5_col6 {
#   background-color: #a7bddb;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row5_col8, #T_4f9d0_row14_col1 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row5_col9 {
#   background-color: #1077b4;
#   color: #f1f1f1;
#   color: black;
# }
# #T_4f9d0_row5_col10, #T_4f9d0_row14_col9 {
#   background-color: #2081b9;
#   color: #f1f1f1;
#   color: black;
# }
# #T_4f9d0_row5_col11 {
#   background-color: #549cc7;
#   color: #f1f1f1;
#   color: black;
# }
# #T_4f9d0_row6_col4 {
#   background-color: #1379b5;
#   color: #f1f1f1;
#   color: black;
# }
# #T_4f9d0_row6_col6 {
#   background-color: #e4e1ef;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row6_col7 {
#   background-color: #faf2f8;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row6_col8 {
#   background-color: #dbdaeb;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row6_col11 {
#   background-color: #9fbad9;
#   color: #000000;
#   color: black;
# }
# #T_4f9d0_row7_col2 {
#   background-color: #529bc7;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row7_col3 {
#   background-color: #adc1dd;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row7_col4 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
#   color: black;
# }
# #T_4f9d0_row7_col5, #T_4f9d0_row12_col2, #T_4f9d0_row14_col6 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row7_col6 {
#   background-color: #d6d6e9;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_4f9d0_row7_col7 {
#   background-color: #e4e1ef;
#   color: #000000;
#   color: black;
# }
# #T_4f9d0_row7_col8, #T_4f9d0_row11_col11 {
#   background-color: #bdc8e1;
#   color: #000000;
#   color

# %%
# Creat a table of differentials - pm2.5 mean
#---------------------------------------------
df = sensor_ld_event_stats_1.iloc[:,[0,8,9,10,11,12,13,14,15]].reset_index().merge(sebbes_pm25_ld_event_desc_mean[['ld_code','pm25_mean','pm25_99%']], 
                                                             left_on='ld_code',
                                                             right_on='ld_code',
                                                             how='left',
                                                             suffixes=(None,'_s')
                                                            ).rename(columns={'pm25_99%':'pm25_p99_s'})

df['dif_pm25_mean'] = df['pm25_mean'] - df['pm25_mean_s']
df['dif_pm25_99'] = df['pm25_p99'] - df['pm25_p99_s']

df = df.rename(columns={'ld_code': 'Event code', 'fname': 'Sensor'})
dif_pm25_mean = df[['Event code','Sensor','dif_pm25_mean']].pivot(index='Sensor',columns='Event code').round(1).droplevel(0, axis=1)
dif_pm25_mean.loc['Mean',:] = dif_pm25_mean.mean(axis=0)
dif_pm25_mean.loc[:,'Mean'] = dif_pm25_mean.mean(axis=1)

tmplist = []
for i, g in sensor_sebbes.groupby(['fname','ld_code']):
    stat, p = wilcoxon(x=g['pm25_mean'].values, y=g['pm25_mean_s'].values) 
    tmplist.append([i[0],i[1],stat,p])
pm25_mean_wilcoxon = pd.DataFrame(tmplist, columns = ['fname','ld_code', 'stat', 'P'])

dif_pm25_p99 = df[['Event code','Sensor','dif_pm25_99']].pivot(index='Sensor',columns='Event code').round(1).droplevel(0, axis=1)
dif_pm25_p99.loc['Mean',:] = dif_pm25_p99.mean(axis=0)
dif_pm25_p99.loc[:,'Mean'] = dif_pm25_p99.mean(axis=1)

tmplist = []
for i, g in sensor_sebbes.groupby(['fname','ld_code']):
    stat, p = wilcoxon(x=g['pm25_p99'].values, y=g['pm25_p99_s'].values) 
    tmplist.append([i[0],i[1],stat,p])
pm25_p99_wilcoxon = pd.DataFrame(tmplist, columns = ['fname','ld_code', 'stat', 'P'])

tmpdfmean = pm25_mean_wilcoxon[['fname','ld_code', 'P']].pivot(index='fname',columns='ld_code').droplevel(0, axis=1)
tmpdfmean.loc['Mean',:] = tmpdfmean.mean(axis=0)
tmpdfmean.loc[:,'Mean'] = tmpdfmean.mean(axis=1)

tmpdfp99 = pm25_p99_wilcoxon[['fname','ld_code', 'P']].pivot(index='fname',columns='ld_code').droplevel(0, axis=1)
tmpdfp99.loc['Mean',:] = tmpdfp99.mean(axis=0)
tmpdfp99.loc[:,'Mean'] = tmpdfp99.mean(axis=1)

display(dif_pm25_mean.style
    .background_gradient(axis=None)
    .applymap(lambda x: color_nan_white_background(x))
    .applymap(lambda x: color_nonnan_black(x))
    .applymap(lambda x: color_nan_white(x))
         .apply(lambda x: np.where(
    tmpdfmean < 0.05,               # Compare DataFrames
    'color: red',  # True Styles
    ''                       # False Styles
), axis=None).apply(lambda x: np.where(
    tmpdfmean < 0.05,               # Compare DataFrames
    'font-weight: bold',  # True Styles
    ''                       # False Styles
), axis=None).format("{:.1f}"),
        dif_pm25_p99.style
    .background_gradient(axis=None)
    .applymap(lambda x: color_nan_white_background(x))
    .applymap(lambda x: color_nonnan_black(x))
    .applymap(lambda x: color_nan_white(x))
         .apply(lambda x: np.where(
    tmpdfmean < 0.05,               # Compare DataFrames
    'color: red',  # True Styles
    ''                       # False Styles
), axis=None).apply(lambda x: np.where(
    tmpdfp99 < 0.05,               # Compare DataFrames
    'font-weight: bold',  # True Styles
    ''                       # False Styles
), axis=None).format("{:.1f}")
       )
# Out:
# <style type="text/css">
# #T_375f3_row0_col0, #T_375f3_row0_col1, #T_375f3_row0_col2, #T_375f3_row0_col3, #T_375f3_row0_col4, #T_375f3_row1_col0, #T_375f3_row1_col1, #T_375f3_row2_col0, #T_375f3_row2_col1, #T_375f3_row2_col2, #T_375f3_row3_col0, #T_375f3_row3_col1, #T_375f3_row5_col0, #T_375f3_row5_col1, #T_375f3_row5_col2, #T_375f3_row5_col3, #T_375f3_row5_col4, #T_375f3_row6_col0, #T_375f3_row6_col1, #T_375f3_row6_col10, #T_375f3_row7_col0, #T_375f3_row7_col1, #T_375f3_row8_col0, #T_375f3_row8_col1, #T_375f3_row9_col0, #T_375f3_row9_col1, #T_375f3_row9_col2, #T_375f3_row9_col3, #T_375f3_row9_col4, #T_375f3_row10_col0, #T_375f3_row10_col1, #T_375f3_row11_col0, #T_375f3_row11_col1, #T_375f3_row13_col0, #T_375f3_row13_col1, #T_375f3_row13_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: white;
#   color: white;
# }
# #T_375f3_row0_col5 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
#   color: black;
# }
# #T_375f3_row0_col6, #T_375f3_row5_col6 {
#   background-color: #b8c6e0;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_375f3_row0_col7 {
#   background-color: #cccfe5;
#   color: #000000;
#   color: black;
# }
# #T_375f3_row0_col8 {
#   background-color: #b3c3de;
#   color: #000000;
#   color: black;
# }
# #T_375f3_row0_col9, #T_375f3_row2_col9, #T_375f3_row10_col2, #T_375f3_row11_col5 {
#   background-color: #c2cbe2;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_375f3_row0_col10 {
#   background-color: #4094c3;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_375f3_row0_col11 {
#   background-color: #a2bcda;
#   color: #000000;
#   color: black;
# }
# #T_375f3_row1_col2 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_375f3_row1_col3 {
#   background-color: #358fc0;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_375f3_row1_col4, #T_375f3_row2_col3 {
#   background-color: #045585;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_375f3_row1_col5, #T_375f3_row2_col5 {
#   background-color: #034c78;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_375f3_row1_col6 {
#   background-color: #569dc8;
#   color: #f1f1f1;
#   color: black;
# }
# #T_375f3_row1_col7 {
#   background-color: #4496c3;
#   color: #f1f1f1;
#   color: black;
# }
# #T_375f3_row1_col8, #T_375f3_row15_col5 {
#   background-color: #529bc7;
#   color: #f1f1f1;
#   color: black;
# }
# #T_375f3_row1_col9, #T_375f3_row5_col10, #T_375f3_row8_col9 {
#   background-color: #80aed2;
#   color: #f1f1f1;
#   color: black;
# }
# #T_375f3_row1_col10 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
#   color: black;
# }
# #T_375f3_row1_col11, #T_375f3_row7_col4 {
#   background-color: #2786bb;
#   color: #f1f1f1;
#   color: black;
# }
# #T_375f3_row2_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_375f3_row2_col6, #T_375f3_row3_col4, #T_375f3_row10_col4 {
#   background-color: #4094c3;
#   color: #f1f1f1;
#   color: black;
# }
# #T_375f3_row2_col7 {
#   background-color: #056aa6;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_375f3_row2_col8 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
#   color: black;
# }
# #T_375f3_row2_col10 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_375f3_row2_col11 {
#   background-color: #1278b4;
#   color: #f1f1f1;
#   color: black;
# }
# #T_375f3_row3_col2 {
#   background-color: #a7bddb;
#   color: #000000;
#   color: black;
# }
# #T_375f3_row3_col3 {
#   background-color: #bbc7e0;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_375f3_row3_col5, #T_375f3_row4_col7, #T_375f3_row8_col2 {
#   background-color: #76aad0;
#   color: #f1f1f1;
#   color: black;
# }
# #T_375f3_row3_col6, #T_375f3_row7_col3 {
#   background-color: #d1d2e6;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_375f3_row3_col7, #T_375f3_row10_col7, #T_375f3_row13_col8 {
#   background-color: #e1dfed;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_375f3_row3_col8 {
#   background-color: #c9cee4;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_375f3_row3_col9 {
#   background-color: #d6d6e9;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_375f3_row3_col10, #T_375f3_row13_col5 {
#   background-color: #83afd3;
#   color: #f1f1f1;
#   color: black;
# }
# #T_375f3_row3_col11 {
#   background-color: #adc1dd;
#   color: #000000;
#   color: black;
# }
# #T_375f3_row4_col0 {
#   background-color: #bdc8e1;
#   color: #000000;
#   color: black;
# }
# #T_375f3_row4_col1, #T_375f3_row4_col10, #T_375f3_row8_col11 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
#   color: black;
# }
# #T_375f3_row4_col2 {
#   background-color: #b3c3de;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_375f3_row4_col3, #T_375f3_row6_col2 {
#   background-color: #a1bbda;
#   color: #000000;
#   color: black;
# }
# #T_375f3_row4_col4 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
#   color: black;
# }
# #T_375f3_row4_col5, #T_375f3_row8_col5 {
#   background-color: #056dab;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_375f3_row4_col6, #T_375f3_row6_col5, #T_375f3_row7_col7 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
#   color: black;
# }
# #T_375f3_row4_col8, #T_375f3_row12_col4 {
#   background-color: #86b0d3;
#   color: #000000;
#   color: black;
# }
# #T_375f3_row4_col9, #T_375f3_row7_col6, #T_375f3_row7_col9 {
#   background-color: #d2d3e7;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_375f3_row4_col11 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
#   color: black;
# }
# #T_375f3_row5_col5 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
#   color: black;
# }
# #T_375f3_row5_col7 {
#   background-color: #bbc7e0;
#   color: #000000;
#   color: black;
# }
# #T_375f3_row5_col8, #T_375f3_row11_col2 {
#   background-color: #c6cce3;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_375f3_row5_col9, #T_375f3_row9_col9, #T_375f3_row10_col3 {
#   background-color: #dedcec;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_375f3_row5_col11 {
#   background-color: #a8bedc;
#   color: #000000;
#   color: black;
# }
# #T_375f3_row6_col3, #T_375f3_row8_col3 {
#   background-color: #c0c9e2;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_375f3_row6_col4 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
#   color: black;
# }
# #T_375f3_row6_col6, #T_375f3_row9_col7, #T_375f3_row13_col9 {
#   background-color: #ebe6f2;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_375f3_row6_col7, #T_375f3_row12_col6 {
#   background-color: #eee8f3;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_375f3_row6_col8, #T_375f3_row9_col8 {
#   background-color: #e5e1ef;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_375f3_row6_col9 {
#   background-color: #e9e5f1;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_375f3_row6_col11 {
#   background-color: #bcc7e1;
#   color: #000000;
#   color: black;
# }
# #T_375f3_row7_col2 {
#   background-color: #a9bfdc;
#   color: #000000;
#   color: black;
# }
# #T_375f3_row7_col5, #T_375f3_row15_col10 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
#   color: black;
# }
# #T_375f3_row7_col8 {
#   background-color: #d8d7e9;
#   color: #000000;
#   color: black;
# }
# #T_375f3_row7_col10, #T_375f3_row14_col2 {
#   background-color: #8fb4d6;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_375f3_row7_col11, #T_375f3_row9_col5 {
#   background-color: #a4bcda;
#   color: #000000;
#   color: black;
# }
# #T_375f3_row8_col4 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
#   color: black;
# }
# #T_375f3_row8_col6, #T_375f3_row8_col7 {
#   background-color: #8fb4d6;
#   color: #000000;
#   color: black;
# }
# #T_375f3_row8_col8 {
#   background-color: #8cb3d5;
#   color: #000000;
#   color: black;
# }
# #T_375f3_row8_col10 {
#   background-color: #0568a3;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   f
# <style type="text/css">
# #T_c1924_row0_col0, #T_c1924_row0_col1, #T_c1924_row0_col2, #T_c1924_row0_col3, #T_c1924_row0_col4, #T_c1924_row1_col0, #T_c1924_row1_col1, #T_c1924_row2_col0, #T_c1924_row2_col1, #T_c1924_row2_col2, #T_c1924_row3_col0, #T_c1924_row3_col1, #T_c1924_row5_col0, #T_c1924_row5_col1, #T_c1924_row5_col2, #T_c1924_row5_col3, #T_c1924_row5_col4, #T_c1924_row6_col0, #T_c1924_row6_col1, #T_c1924_row6_col10, #T_c1924_row7_col0, #T_c1924_row7_col1, #T_c1924_row8_col0, #T_c1924_row8_col1, #T_c1924_row9_col0, #T_c1924_row9_col1, #T_c1924_row9_col2, #T_c1924_row9_col3, #T_c1924_row9_col4, #T_c1924_row10_col0, #T_c1924_row10_col1, #T_c1924_row11_col0, #T_c1924_row11_col1, #T_c1924_row13_col0, #T_c1924_row13_col1, #T_c1924_row13_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: white;
#   color: white;
# }
# #T_c1924_row0_col5 {
#   background-color: #328dbf;
#   color: #f1f1f1;
#   color: black;
#   font-weight: bold;
# }
# #T_c1924_row0_col6, #T_c1924_row7_col3, #T_c1924_row9_col11 {
#   background-color: #c1cae2;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_c1924_row0_col7 {
#   background-color: #e6e2ef;
#   color: #000000;
#   color: black;
#   font-weight: bold;
# }
# #T_c1924_row0_col8, #T_c1924_row8_col7 {
#   background-color: #d2d3e7;
#   color: #000000;
#   color: black;
#   font-weight: bold;
# }
# #T_c1924_row0_col9 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_c1924_row0_col10 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
#   color: black;
#   color: red;
# }
# #T_c1924_row0_col11, #T_c1924_row2_col6 {
#   background-color: #94b6d7;
#   color: #000000;
#   color: black;
#   font-weight: bold;
# }
# #T_c1924_row1_col2 {
#   background-color: #0570b0;
#   color: #f1f1f1;
#   color: black;
#   color: red;
# }
# #T_c1924_row1_col3 {
#   background-color: #4496c3;
#   color: #f1f1f1;
#   color: black;
#   color: red;
# }
# #T_c1924_row1_col4 {
#   background-color: #045c90;
#   color: #f1f1f1;
#   color: black;
#   color: red;
# }
# #T_c1924_row1_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
#   color: black;
#   color: red;
# }
# #T_c1924_row1_col6 {
#   background-color: #8cb3d5;
#   color: #000000;
#   color: black;
#   font-weight: bold;
# }
# #T_c1924_row1_col7 {
#   background-color: #b5c4df;
#   color: #000000;
#   color: black;
#   font-weight: bold;
# }
# #T_c1924_row1_col8 {
#   background-color: #a2bcda;
#   color: #000000;
#   color: black;
#   font-weight: bold;
# }
# #T_c1924_row1_col9 {
#   background-color: #4295c3;
#   color: #f1f1f1;
#   color: black;
#   font-weight: bold;
# }
# #T_c1924_row1_col10 {
#   background-color: #0569a4;
#   color: #f1f1f1;
#   color: black;
# }
# #T_c1924_row1_col11, #T_c1924_row8_col9 {
#   background-color: #308cbe;
#   color: #f1f1f1;
#   color: black;
# }
# #T_c1924_row2_col3 {
#   background-color: #1077b4;
#   color: #f1f1f1;
#   color: black;
#   color: red;
# }
# #T_c1924_row2_col4 {
#   background-color: #0568a3;
#   color: #f1f1f1;
#   color: black;
#   color: red;
# }
# #T_c1924_row2_col5 {
#   background-color: #045b8e;
#   color: #f1f1f1;
#   color: black;
#   color: red;
# }
# #T_c1924_row2_col7, #T_c1924_row4_col9, #T_c1924_row5_col9 {
#   background-color: #89b1d4;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_c1924_row2_col8 {
#   background-color: #86b0d3;
#   color: #000000;
#   color: black;
#   font-weight: bold;
# }
# #T_c1924_row2_col9, #T_c1924_row11_col2 {
#   background-color: #79abd0;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_c1924_row2_col10 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
#   color: black;
#   color: red;
# }
# #T_c1924_row2_col11 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
#   color: black;
# }
# #T_c1924_row3_col2 {
#   background-color: #549cc7;
#   color: #f1f1f1;
#   color: black;
#   font-weight: bold;
# }
# #T_c1924_row3_col3, #T_c1924_row6_col3 {
#   background-color: #bbc7e0;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_c1924_row3_col4 {
#   background-color: #358fc0;
#   color: #f1f1f1;
#   color: black;
# }
# #T_c1924_row3_col5 {
#   background-color: #358fc0;
#   color: #f1f1f1;
#   color: black;
#   font-weight: bold;
# }
# #T_c1924_row3_col6 {
#   background-color: #d6d6e9;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_c1924_row3_col7 {
#   background-color: #f3edf5;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_c1924_row3_col8, #T_c1924_row15_col0 {
#   background-color: #dbdaeb;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_c1924_row3_col9, #T_c1924_row11_col5 {
#   background-color: #8bb2d4;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_c1924_row3_col10, #T_c1924_row14_col10 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
#   color: black;
#   font-weight: bold;
# }
# #T_c1924_row3_col11, #T_c1924_row4_col6 {
#   background-color: #99b8d8;
#   color: #000000;
#   color: black;
#   font-weight: bold;
# }
# #T_c1924_row4_col0, #T_c1924_row5_col7 {
#   background-color: #c0c9e2;
#   color: #000000;
#   color: black;
#   font-weight: bold;
# }
# #T_c1924_row4_col1 {
#   background-color: #cdd0e5;
#   color: #000000;
#   color: black;
#   font-weight: bold;
# }
# #T_c1924_row4_col2 {
#   background-color: #509ac6;
#   color: #f1f1f1;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_c1924_row4_col3 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
#   color: black;
#   font-weight: bold;
# }
# #T_c1924_row4_col4, #T_c1924_row14_col4, #T_c1924_row14_col5 {
#   background-color: #056ead;
#   color: #f1f1f1;
#   color: black;
# }
# #T_c1924_row4_col5 {
#   background-color: #045d92;
#   color: #f1f1f1;
#   color: black;
#   color: red;
# }
# #T_c1924_row4_col7 {
#   background-color: #c1cae2;
#   color: #000000;
#   color: black;
#   font-weight: bold;
# }
# #T_c1924_row4_col8, #T_c1924_row8_col6 {
#   background-color: #9cb9d9;
#   color: #000000;
#   color: black;
#   font-weight: bold;
# }
# #T_c1924_row4_col10 {
#   background-color: #167bb6;
#   color: #f1f1f1;
#   color: black;
# }
# #T_c1924_row4_col11 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
#   color: black;
# }
# #T_c1924_row5_col5 {
#   background-color: #0566a0;
#   color: #f1f1f1;
#   color: black;
# }
# #T_c1924_row5_col6 {
#   background-color: #b4c4df;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_c1924_row5_col8 {
#   background-color: #b5c4df;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_c1924_row5_col10 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
#   color: black;
#   font-weight: bold;
# }
# #T_c1924_row5_col11 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
#   color: black;
# }
# #T_c1924_row6_col2 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
#   color: black;
#   font-weight: bold;
# }
# #T_c1924_row6_col4, #T_c1924_row10_col4 {
#   background-color: #2081b9;
#   color: #f1f1f1;
#   color: black;
# }
# #T_c1924_row6_col5 {
#   background-color: #2484ba;
#   color: #f1f1f1;
#   color: black;
# }
# #T_c1924_row6_col6, #T_c1924_row9_col8 {
#   background-color: #e7e3f0;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_c1924_row6_col7 {
#   background-color: #faf2f8;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_c1924_row6_col8 {
#   background-color: #e3e0ee;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_c1924_row6_col9 {
#   background-color: #a1bbda;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_c1924_row6_col11 {
#   background-color: #a7bddb;
#   color: #000000;
#   color: black;
# }
# #T_c1924_row7_col2 {
#   background-color: #589ec8;
#   color: #f1f1f1;
#   color: black;
#   font-weight: bold;
# }
# #T_c1924_row7_col4 {
#   background-color: #197db7;
#   color: #f1f1f1;
#   color: black;
# }
# #T_c1924_row7_col5 {
#   background-color: #2786bb;
#   color: #f1f1f1;
#   color: black;
# }
# #T_c1924_row7_col6 {
#   background-color: #d2d2e7;
#   color: #000000;
#   color: black;
#   color: red;
#   font-weight: bold;
# }
# #T_c1924_row7_col7 {
#   background-color: #cacee5;
#   color: #000000;
#   color: black;
# }
# #T_c1924_row7_col8 {
#   background-color: #d3d4e7;
#   color: #000000;
#   color: black;
#   font-weight: bold;
# }
# #T_c1924_row7_col9 {
#   background-color: #86b0d3;

# %%
# Heat map analysis
#-------------------
fig, ((ax1, ax2),(ax3, ax4))  = plt.subplots(2,2, figsize=(17,15))

sns.heatmap(dif_pm10_mean, annot=True, cmap='coolwarm', robust=True, ax=ax1, linewidths=.5, vmin=-8, vmax=8)
tmpdf = pm10_mean_wilcoxon[['fname','ld_code', 'P'
                          ]].pivot(index='fname',columns='ld_code').droplevel([0], axis=1
                                            ).reset_index(drop=True
                                                         ).T.reset_index(drop=True
                                                                        ).T.stack()
tmpdf = tmpdf[tmpdf > 0.05]
t = tmpdf.index.values.tolist()
for i in t:
    ax1.add_patch(Rectangle((i[1], i[0]), 1, 1, fill=False, edgecolor='black', lw=2, hatch='//'))

sns.heatmap(dif_pm10_p99, annot=True, cmap='coolwarm', robust=True, ax=ax2, linewidths=.5, center=0, vmin=-30, vmax=10)
tmpdf = pm10_p99_wilcoxon[['fname','ld_code', 'P'
                          ]].pivot(index='fname',columns='ld_code').droplevel([0], axis=1
                                            ).reset_index(drop=True
                                                         ).T.reset_index(drop=True
                                                                        ).T.stack()
tmpdf = tmpdf[tmpdf > 0.05]
t = tmpdf.index.values.tolist()
for i in t:
    ax2.add_patch(Rectangle((i[1], i[0]), 1, 1, fill=False, edgecolor='black', lw=2, hatch='//'))

# pm2.5
#-------
sns.heatmap(dif_pm25_mean, annot=True, cmap='coolwarm', robust=True, ax=ax3, linewidths=.5, vmin=-8, vmax=8)
tmpdf = pm25_mean_wilcoxon[['fname','ld_code', 'P'
                          ]].pivot(index='fname',columns='ld_code').droplevel([0], axis=1
                                            ).reset_index(drop=True
                                                         ).T.reset_index(drop=True
                                                                        ).T.stack()
tmpdf = tmpdf[tmpdf > 0.05]
t = tmpdf.index.values.tolist()
for i in t:
    ax3.add_patch(Rectangle((i[1], i[0]), 1, 1, fill=False, edgecolor='black', lw=2, hatch='//'))

sns.heatmap(dif_pm25_p99, annot=True, cmap='coolwarm', robust=True, ax=ax4, linewidths=.5, center=0, vmin=-30, vmax=10)
tmpdf = pm25_p99_wilcoxon[['fname','ld_code', 'P'
                          ]].pivot(index='fname',columns='ld_code').droplevel([0], axis=1
                                            ).reset_index(drop=True
                                                         ).T.reset_index(drop=True
                                                                        ).T.stack()
tmpdf = tmpdf[tmpdf > 0.05]
t = tmpdf.index.values.tolist()
for i in t:
    ax4.add_patch(Rectangle((i[1], i[0]), 1, 1, fill=False, edgecolor='black', lw=2, hatch='//'))
    
ax1.set_title('Average daily mean PM10 by lockdown event', y=1.01, x=0, fontsize=13)    
ax2.set_title('Average daily 99%ile PM10 by lockdown event', y=1.01, x=0, fontsize=13)    
ax3.set_title('Average daily mean PM2.5 by lockdown event', y=1.01, x=0, fontsize=13)
ax4.set_title('Average daily 99%ile PM2.5 by lockdown event', y=1.01, x=0, fontsize=13)
ax1.set_xlabel('Lockdown event code', fontsize=11)
ax1.set_ylabel('Sensor location', fontsize=11)
ax2.set_xlabel('Lockdown event code', fontsize=11)
ax2.set_ylabel('Sensor location', fontsize=11)
ax3.set_xlabel('Lockdown event code', fontsize=11)
ax3.set_ylabel('Sensor location', fontsize=11)
ax4.set_xlabel('Lockdown event code', fontsize=11)
ax4.set_ylabel('Sensor location', fontsize=11)

fig.suptitle('Measured differentials in PM concentration metrics during 2020-21 COVID-19 pandemic restriction events relative to typical levels experienced 2016-21 in Oxford, UK.\nDifferences shown in mass units (ug/m3). All changes statistically significant differences unless denoted by shading.', fontsize=14, y=1)

plt.tight_layout() 
plt.savefig(stats_home+'sensor_vs_typical_year_heatmap_24hrmean_p99_1619.png')

plt.show()

# %%
dif_pm10_p99.describe().round()
# Out:
# Event code     a     b     c     d     e     f     g     h     i     j     k  \
# count        4.0   4.0  11.0  13.0  13.0  16.0  16.0  16.0  16.0  16.0  15.0
# mean       -16.0 -13.0  -4.0 -12.0  -1.0  -6.0 -17.0 -19.0 -14.0  -7.0  -4.0
# std          2.0   5.0   4.0   6.0   5.0   4.0   5.0   9.0  10.0   5.0   5.0
# min        -19.0 -19.0  -8.0 -19.0 -10.0 -11.0 -24.0 -28.0 -24.0 -14.0 -11.0
# 25%        -17.0 -14.0  -7.0 -16.0  -4.0  -8.0 -21.0 -26.0 -21.0 -11.0  -7.0
# 50%        -15.0 -12.0  -6.0 -15.0  -2.0  -7.0 -19.0 -22.0 -17.0  -8.0  -6.0
# 75%        -15.0 -10.0  -5.0 -11.0   0.0  -1.0 -13.0 -14.0  -8.0  -2.0  -2.0
# max        -14.0  -8.0   6.0   4.0  11.0   0.0  -7.0   2.0   9.0   5.0   9.0
#
# Event code  Mean
# count       16.0
# mean       -10.0
# std          6.0
# min        -18.0
# 25%        -13.0
# 50%        -12.0
# 75%         -6.0
# max          2.0

# %%
# Creat a table of differentials - pm10 percentages
#---------------------------------------------------
df = sensor_ld_event_stats_1.iloc[:,[0,1,2,3,4,5,6,7,8]].reset_index().merge(sebbes_pm10_ld_event_desc_mean[['ld_code','pm10_mean','pm10_99%']], 
                                                             left_on='ld_code',
                                                             right_on='ld_code',
                                                             how='left',
                                                             suffixes=(None,'_s')
                                                            ).rename(columns={'pm10_99%':'pm10_p99_s'})
df['pdif_pm10_mean'] = (( df['pm10_mean'] - df['pm10_mean_s'] ) / df['pm10_mean_s'] ) * 100
df['pdif_pm10_99'] = (( df['pm10_p99'] - df['pm10_p99_s'] ) / df['pm10_p99_s'] ) * 100

df = df.rename(columns={'ld_code': 'Event code', 'fname': 'Sensor'})
pdif_pm10_mean = df[['Event code','Sensor','pdif_pm10_mean']].pivot(index='Sensor',columns='Event code').round(1).droplevel(0, axis=1)
pdif_pm10_mean.loc['Mean',:] = pdif_pm10_mean.mean(axis=0)
pdif_pm10_mean.loc[:,'Mean'] = pdif_pm10_mean.mean(axis=1)

tmplist = []
for i, g in sensor_sebbes.groupby(['fname','ld_code']):
    stat, p = wilcoxon(g['pm10_mean'].values, g['pm10_mean_s'].values) 
    tmplist.append([i[0],i[1],stat,p])
ppm10_mean_wilcoxon = pd.DataFrame(tmplist, columns = ['fname','ld_code', 'stat', 'P'])

pdif_pm10_p99 = df[['Event code','Sensor','pdif_pm10_99']].pivot(index='Sensor',columns='Event code').round(1).droplevel(0, axis=1)
pdif_pm10_p99.loc['Mean',:] = pdif_pm10_p99.mean(axis=0)
pdif_pm10_p99.loc[:,'Mean'] = pdif_pm10_p99.mean(axis=1)

tmplist = []
for i, g in sensor_sebbes.groupby(['fname','ld_code']):
    stat, p = wilcoxon(g['pm10_p99'].values, g['pm10_p99_s'].values) 
    tmplist.append([i[0],i[1],stat,p])
ppm10_p99_wilcoxon = pd.DataFrame(tmplist, columns = ['fname','ld_code', 'stat', 'P'])

ppm10_mean_wilcoxon_a = pm10_mean_wilcoxon[['fname','ld_code', 'P']].pivot(index='fname',columns='ld_code').droplevel(0, axis=1)
ppm10_mean_wilcoxon_a.loc['Mean',:] = ppm10_mean_wilcoxon_a.mean(axis=0)
ppm10_mean_wilcoxon_a.loc[:,'Mean'] = ppm10_mean_wilcoxon_a.mean(axis=1)

ppm10_p99_wilcoxon_a = pm10_p99_wilcoxon[['fname','ld_code', 'P']].pivot(index='fname',columns='ld_code').droplevel(0, axis=1)
ppm10_p99_wilcoxon_a.loc['Mean',:] = ppm10_p99_wilcoxon_a.mean(axis=0)
ppm10_p99_wilcoxon_a.loc[:,'Mean'] = ppm10_p99_wilcoxon_a.mean(axis=1)


# Creat a table of differentials - pm2.5 percentages
#----------------------------------------------------
df = sensor_ld_event_stats_1.iloc[:,[0,8,9,10,11,12,13,14,15]].reset_index().merge(sebbes_pm25_ld_event_desc_mean[['ld_code','pm25_mean','pm25_99%']], 
                                                             left_on='ld_code',
                                                             right_on='ld_code',
                                                             how='left',
                                                             suffixes=(None,'_s')
                                                            ).rename(columns={'pm25_99%':'pm25_p99_s'})

df['pdif_pm25_mean'] = (( df['pm25_mean'] - df['pm25_mean_s'] ) / df['pm25_mean_s'] ) * 100
df['pdif_pm25_99'] = (( df['pm25_p99'] - df['pm25_p99_s'] ) / df['pm25_p99_s'] ) * 100

df = df.rename(columns={'ld_code': 'Event code', 'fname': 'Sensor'})
pdif_pm25_mean = df[['Event code','Sensor','pdif_pm25_mean']].pivot(index='Sensor',columns='Event code').round(1).droplevel(0, axis=1)
pdif_pm25_mean.loc['Mean',:] = pdif_pm25_mean.mean(axis=0)
pdif_pm25_mean.loc[:,'Mean'] = pdif_pm25_mean.mean(axis=1)

tmplist = []
for i, g in sensor_sebbes.groupby(['fname','ld_code']):
    stat, p = wilcoxon(x=g['pm25_mean'].values, y=g['pm25_mean_s'].values) 
    tmplist.append([i[0],i[1],stat,p])
ppm25_mean_wilcoxon = pd.DataFrame(tmplist, columns = ['fname','ld_code', 'stat', 'P'])

pdif_pm25_p99 = df[['Event code','Sensor','pdif_pm25_99']].pivot(index='Sensor',columns='Event code').round(1).droplevel(0, axis=1)
pdif_pm25_p99.loc['Mean',:] = pdif_pm25_p99.mean(axis=0)
pdif_pm25_p99.loc[:,'Mean'] = pdif_pm25_p99.mean(axis=1)

tmplist = []
for i, g in sensor_sebbes.groupby(['fname','ld_code']):
    stat, p = wilcoxon(x=g['pm25_p99'].values, y=g['pm25_p99_s'].values) 
    tmplist.append([i[0],i[1],stat,p])
ppm25_p99_wilcoxon = pd.DataFrame(tmplist, columns = ['fname','ld_code', 'stat', 'P'])

ptmpdfmean = pm25_mean_wilcoxon[['fname','ld_code', 'P']].pivot(index='fname',columns='ld_code').droplevel(0, axis=1)
ptmpdfmean.loc['Mean',:] = ptmpdfmean.mean(axis=0)
ptmpdfmean.loc[:,'Mean'] = ptmpdfmean.mean(axis=1)

ptmpdfp99 = pm25_p99_wilcoxon[['fname','ld_code', 'P']].pivot(index='fname',columns='ld_code').droplevel(0, axis=1)
ptmpdfp99.loc['Mean',:] = ptmpdfp99.mean(axis=0)
ptmpdfp99.loc[:,'Mean'] = ptmpdfp99.mean(axis=1)

# %%
# Heat map analysis - percentages
#---------------------------------
fig, ((ax1, ax2),(ax3, ax4))  = plt.subplots(2,2, figsize=(17,15))

# pm10
#------
sns.heatmap(pdif_pm10_mean, annot=True, cmap='coolwarm', robust=True, ax=ax1, linewidths=.5, vmin=-50, vmax=50)
tmpdf = pm10_mean_wilcoxon[['fname','ld_code', 'P'
                          ]].pivot(index='fname',columns='ld_code').droplevel([0], axis=1
                                            ).reset_index(drop=True
                                                         ).T.reset_index(drop=True
                                                                        ).T.stack()
tmpdf = tmpdf[tmpdf > 0.05]
t = tmpdf.index.values.tolist()
for i in t:
    ax1.add_patch(Rectangle((i[1], i[0]), 1, 1, fill=False, edgecolor='black', lw=2, hatch='//'))

sns.heatmap(pdif_pm10_p99, annot=True, cmap='coolwarm', robust=True, ax=ax2, linewidths=.5, vmin=-60, vmax=40)
tmpdf = pm10_p99_wilcoxon[['fname','ld_code', 'P'
                          ]].pivot(index='fname',columns='ld_code').droplevel([0], axis=1
                                            ).reset_index(drop=True
                                                         ).T.reset_index(drop=True
                                                                        ).T.stack()
tmpdf = tmpdf[tmpdf > 0.05]
t = tmpdf.index.values.tolist()
for i in t:
    ax2.add_patch(Rectangle((i[1], i[0]), 1, 1, fill=False, edgecolor='black', lw=2, hatch='//'))

# pm2.5
#-------
sns.heatmap(pdif_pm25_mean, annot=True, cmap='coolwarm', robust=True, ax=ax3, linewidths=.5, vmin=-50, vmax=50)
tmpdf = pm25_mean_wilcoxon[['fname','ld_code', 'P'
                          ]].pivot(index='fname',columns='ld_code').droplevel([0], axis=1
                                            ).reset_index(drop=True
                                                         ).T.reset_index(drop=True
                                                                        ).T.stack()
tmpdf = tmpdf[tmpdf > 0.05]
t = tmpdf.index.values.tolist()
for i in t:
    ax3.add_patch(Rectangle((i[1], i[0]), 1, 1, fill=False, edgecolor='black', lw=2, hatch='//'))

sns.heatmap(pdif_pm25_p99, annot=True, cmap='coolwarm', robust=True, ax=ax4, linewidths=.5, vmin=-60, vmax=40)
tmpdf = pm25_p99_wilcoxon[['fname','ld_code', 'P'
                          ]].pivot(index='fname',columns='ld_code').droplevel([0], axis=1
                                            ).reset_index(drop=True
                                                         ).T.reset_index(drop=True
                                                                        ).T.stack()
tmpdf = tmpdf[tmpdf > 0.05]
t = tmpdf.index.values.tolist()
for i in t:
    ax4.add_patch(Rectangle((i[1], i[0]), 1, 1, fill=False, edgecolor='black', lw=2, hatch='//'))
    
ax1.set_title('Average daily mean PM10 by lockdown event', y=1.01, x=0, fontsize=13)    
ax2.set_title('Average daily 99%ile PM10 by lockdown event', y=1.01, x=0, fontsize=13)    
ax3.set_title('Average daily mean PM2.5 by lockdown event', y=1.01, x=0, fontsize=13)
ax4.set_title('Average daily 99%ile PM2.5 by lockdown event', y=1.01, x=0, fontsize=13)
ax1.set_xlabel('Lockdown event code', fontsize=11)
ax1.set_ylabel('Sensor location', fontsize=11)
ax2.set_xlabel('Lockdown event code', fontsize=11)
ax2.set_ylabel('Sensor location', fontsize=11)
ax3.set_xlabel('Lockdown event code', fontsize=11)
ax3.set_ylabel('Sensor location', fontsize=11)
ax4.set_xlabel('Lockdown event code', fontsize=11)
ax4.set_ylabel('Sensor location', fontsize=11)

fig.suptitle('Measured differentials in percentage terms for PM concentration metrics during 2020-21 COVID-19 pandemic restriction events relative to typical levels experienced 2016-21 in Oxford, UK. \nDifferences shown in mass units (ug/m3). All changes statistically significant differences unless denoted by shading.', fontsize=14, y=1)

plt.tight_layout() 
plt.savefig(stats_home+'sensor_vs_typical_year_heatmap_24hrmean_p99_%_1619.png')

plt.show()
